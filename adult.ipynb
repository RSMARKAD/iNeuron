# %%
#Problem statement-1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('adult.csv')

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.head() #data cleaning
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data.shape #Define the shape
# Out:
# (32561, 15)

# %%
data.isnull # finde out null value
# Out:
# <bound method DataFrame.isnull of        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
data.isnull().sum() # sum of all null values
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
 data.columns # Find out the columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
data.dropna(inplace=True)

# %%
data.shape # after drapping null value and check the shape
# Out:
# (32561, 15)

# %%
data.set_index('age', inplace=True) # set the age column of a index position

# %%
data.columns # chech the colums
# Out:
# Index(['workclass', 'fnlwgt', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
data['salary'].value_counts() # Total salary counts
# Out:
#  <=50K    24720
#  >50K      7841
# Name: salary, dtype: int64

# %%
data['relationship']
# Out:
# age
# 39     Not-in-family
# 50           Husband
# 38     Not-in-family
# 53           Husband
# 28              Wife
#            ...
# 27              Wife
# 40           Husband
# 58         Unmarried
# 22         Own-child
# 52              Wife
# Name: relationship, Length: 32561, dtype: object

# %%
data['relationship'].value_counts(ascending=True)
# Out:
#  Other-relative      981
#  Wife               1568
#  Unmarried          3446
#  Own-child          5068
#  Not-in-family      8305
#  Husband           13193
# Name: relationship, dtype: int64

# %%
data['marital-status']
# Out:
# age
# 39          Never-married
# 50     Married-civ-spouse
# 38               Divorced
# 53     Married-civ-spouse
# 28     Married-civ-spouse
#              ...
# 27     Married-civ-spouse
# 40     Married-civ-spouse
# 58                Widowed
# 22          Never-married
# 52     Married-civ-spouse
# Name: marital-status, Length: 32561, dtype: object

# %%
data['occupation']
# Out:
# age
# 39          Adm-clerical
# 50       Exec-managerial
# 38     Handlers-cleaners
# 53     Handlers-cleaners
# 28        Prof-specialty
#              ...
# 27          Tech-support
# 40     Machine-op-inspct
# 58          Adm-clerical
# 22          Adm-clerical
# 52       Exec-managerial
# Name: occupation, Length: 32561, dtype: object

# %%
data['relationship']
# Out:
# age
# 39     Not-in-family
# 50           Husband
# 38     Not-in-family
# 53           Husband
# 28              Wife
#            ...
# 27              Wife
# 40           Husband
# 58         Unmarried
# 22         Own-child
# 52              Wife
# Name: relationship, Length: 32561, dtype: object

# %%
data.loc[data['hours-per-week']== 13]
# Out:
#              workclass  fnlwgt      education  education-num  \
# age
# 50    Self-emp-not-inc   83311      Bachelors             13
# 24           State-gov  166851        Masters             14
# 22             Private   74631   Some-college             10
# 76             Private  199949            9th              5
# 32             Private  136935        HS-grad              9
# 18             Private  577521           11th              7
# 25                   ?  219987     Assoc-acdm             12
# 19             Private   60367        HS-grad              9
# 57    Self-emp-not-inc  291529      Bachelors             13
# 31           State-gov  123037   Some-college             10
# 84             Private  132806        HS-grad              9
# 71             Private  217971            9th              5
# 25                   ?  239120      Bachelors             13
# 29           Local-gov  167544     Assoc-acdm             12
# ...

# %%
data.loc[data['hours-per-week']== 13][['salary','education']]
# Out:
#      salary      education
# age
# 50    <=50K      Bachelors
# 24    <=50K        Masters
# 22    <=50K   Some-college
# 76    <=50K            9th
# 32    <=50K        HS-grad
# 18    <=50K           11th
# 25    <=50K     Assoc-acdm
# 19    <=50K        HS-grad
# 57     >50K      Bachelors
# 31    <=50K   Some-college
# 84    <=50K        HS-grad
# 71    <=50K            9th
# 25    <=50K      Bachelors
# 29    <=50K     Assoc-acdm
# 20    <=50K   Some-college
# 66    <=50K        HS-grad
# 37     >50K     Assoc-acdm
# 17    <=50K           11th
# 76    <=50K        HS-grad
# 21    <=50K        HS-grad
# 48    <=50K    Prof-school
# 75    <=50K   Some-college
# 69    <=50K        HS-grad

# %%
data['relationship'].value_counts().plot(kind='bar')
plt.title('relationship of family members')
plt.xlabel('Family Members')
plt.ylabel('Counts')
plt.show()

# %%
data['education-num'].value_counts().sort_index().plot(kind='bar', color = ['#354259'])
data['education'].value_counts().sort_index().plot(kind='bar',color = ['#F73D93'])
plt.title('education and education-num for Family')
plt.xlabel('Education and num')
plt.ylabel('Counts')
plt.show()

# %%
data['marital-status'].value_counts().sort_index().plot(kind='bar', color = 'g')
data['occupation'].value_counts().sort_index().plot(kind='bar',color = ['#D2691E'])
plt.title('marital-status and occupation for Family')
plt.xlabel('marital-status and occupation')
plt.ylabel('Counts')
plt.show()

# %%
data['workclass']
# Out:
# age
# 39            State-gov
# 50     Self-emp-not-inc
# 38              Private
# 53              Private
# 28              Private
#             ...
# 27              Private
# 40              Private
# 58              Private
# 22              Private
# 52         Self-emp-inc
# Name: workclass, Length: 32561, dtype: object

# %%
data['workclass'].value_counts().sort_index().plot(kind='bar', color = 'g')
plt.title('workclass for Family')
plt.xlabel('workclass')
plt.ylabel('Counts')
plt.show()

# %%
data['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
data['education'].value_counts().sort_index().plot(kind='bar', color = 'y')
plt.title('education for Family')
plt.xlabel('education')
plt.ylabel('Counts')
plt.show()
